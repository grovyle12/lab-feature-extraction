# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/mauri/Documents/Important IH Files/ipynb files/unit4.csv')

# %%
df_cat = df.select_dtypes(object)
df_cat.head()
# Out:
#   STATE PVASTATE MDMAUD RECP3 GENDER DOMAIN HOMEOWNR VETERANS RFA_2
# 0    IL            XXXX            F     T2                     L4E
# 1    CA            XXXX            M     S1        H            L2G
# 2    NC            XXXX            M     R2        U            L4E
# 3    CA            XXXX            F     R2        U            L4E
# 4    FL            XXXX     X      F     S2        H            L2F

# %%
df['RFA_2'].value_counts()
# Out:
# L1F    29207
# L1G    12007
# L2F    10398
# L3E     7244
# L2E     4681
# L1E     4667
# L4D     4449
# L2G     4410
# L4E     3647
# L3F     3352
# L3D     2267
# L4F     1951
# L3G     1425
# L4G      864
# Name: RFA_2, dtype: int64

# %%
val
# Out:
# array([29207, 12007, 10398,  7244,  4681,  4667,  4449,  4410,  3647,
#         3352,  2267,  1951,  1425,   864], dtype=int64)

# %%
for i in (df_cat.columns):
    fig, ax = plt.subplots(figsize = (35,10))
    ax = sns.countplot(df_cat[i], order = df_cat[i].value_counts().index)
    val = df[i].value_counts(ascending=False).values
    ax.bar_label(container=ax.containers[0], labels=val)
    plt.title(i)
# Out:
# C:\Users\mauri\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mauri\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?

# %% [markdown]
# We should drop them. PVAState, MDMAUD, RECP3, and Vetern have a large amount of singular values.

# %%
df.head()
# Out:
#   STATE PVASTATE   DOB MDMAUD RECP3 GENDER DOMAIN  INCOME HOMEOWNR   HV1  \
# 0    IL           3712   XXXX            F     T2     NaN            479
# 1    CA           5202   XXXX            M     S1     6.0        H  5468
# 2    NC              0   XXXX            M     R2     3.0        U   497
# 3    CA           2801   XXXX            F     R2     1.0        U  1000
# 4    FL           2001   XXXX     X      F     S2     3.0        H   576
#
#     HV2  HV3  HV4   IC1   IC2   IC3   IC4    IC5 VETERANS  NUMPROM  CARDPROM  \
# 0   635    3    2   307   318   349   378  12883                74        27
# 1  5218   12   10  1088  1096  1026  1037  36175                32        12
# 2   546    2    1   251   292   292   340  11576                63        26
# 3  1263    2    1   386   388   396   423  15130                66        27
# 4   594    4    3   240   250   293   321   9836               113        43
#
# ...

# %% [markdown]
# ## Plot time variable. Can you extract something from it?
